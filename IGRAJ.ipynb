# %%
# !pip install pandas
# !pip install numpy

import pandas as pd
import numpy as np

ignore_top_N_stopwords = 2
ignore_word_with_less_than_M_occurences = 2

eta = 0.1
#dajem putoanju do datoteka i kategoriziram podatke
train = pd.read_csv("C:\\Users\\Marta\\Desktop\\Uvod-u-umjetnu-inteligenciju-main\\500train.csv",header=None, delimiter=',',names=
                   ["TARGET","TITLE","REVIEW"])
test = pd.read_csv("C:\\Users\\Marta\\Desktop\\Uvod-u-umjetnu-inteligenciju-main\\20test.csv" ,header=None, delimiter=',',names=
                   ["TARGET","TITLE","REVIEW"])
#uvodim nazive za review i target
train_review = train[["REVIEW"]] 
test_review = test[["REVIEW"]]
train_targets = train[["TARGET"]]
test_targets = test[["TARGET"]]
#test.head()
#ovdje spajamo polja
all_reviews = [train_review, test_review] 
combined = pd.concat(all_reviews)
#od polja radimo liste
combined_as_list = [item for sublist in combined.values.tolist() for item in sublist]
#razdvajanje riječi zasebno u svaki red
combined_as_list_of_words = [x.split(" ") for x in combined_as_list]
LoW = [item.lower() for sublist in combined_as_list_of_words for item in sublist]
#nema ponavljanja riječi 
SoW = set(LoW)

#petlja koja ce izbrojati koliko puta se neka rijec ponavlja, finlist je finalna lista u koju spremamo taj podatak
FinList = []
for word in SoW:
	counter = 0
	for word1 in LoW:
		if word1 == word:
			counter = counter + 1
	FinList.append([counter, word])

#valjda je odvojio prva dva clana,tj. najcesce rijeci i one koje su se pojavile manje od dva puta
FinList.sort(reverse=True)
FinFinList = FinList[ignore_top_N_stopwords:]
FINAL = [x for x in FinFinList if x[0]>ignore_word_with_less_than_M_occurences]
# Out:
# Requirement already satisfied: pandas in c:\users\marta\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marta\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\marta\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\marta\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\marta\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\marta\anaconda3\lib\site-packages (1.21.5)
# [[1068, 'i'],
#  [998, 'a'],
#  [977, 'to'],
#  [903, 'of'],
#  [762, 'is'],
#  [730, 'this'],
#  [625, 'it'],
#  [522, 'in'],
#  [423, 'for'],
#  [399, 'that'],
#  [342, 'was'],
#  [326, 'not'],
#  [292, 'you'],
#  [272, 'but'],
#  [271, 'my'],
#  [269, 'with'],
#  [256, 'are'],
#  [254, 'book'],
#  [248, 'have'],
#  [240, 'on'],
#  [204, 'as'],
#  [186, 'be'],
#  [180, 'one'],
#  [155, 'so'],
#  [153, 'all'],
#  [152, 'just'],
#  [150, 'like'],
#  [145, 'very'],
#  [142, 'if'],
#  [142, 'from'],
#  [133, 'has'],
#  [130, 'at'],
#  [130, 'an'],
#  [129, 'about'],
#  [125, 'they'],
#  [118, 'or'],
#  [114, 'would'],
#  [113, 'her'],
#  [109, 'by'],
#  [107, 'me'],
#  [105, 'what'],
#  [99, 'read'],
#  [98, 'who'],
#  [98, 'when'],
#  [98, 'she'],
#  [93, 'great'],
#  [93, 'can'],
#  [92, 'some'],
#  [91, 'up'],
#  [90, 'love'],
#  [90, 'get'],
#  [88, 'out'],
#  [88, 'no'],
#  [87, 'only'],
#  [86, 'more'],
#  [86, 'it.'],
#  [86, 'good'],
#  [83, 'there'],
#  [83, 'had'],
#  [83, '-'],
#  [82, 'will'],
#  [78, 'really'],
#  [78, 'he'],
#  [76, 'his'],
#  [75, 'other'],
#  [74, "it's"],
#  [74, 'even'],
#  [70, 'them'],
#  [66, 'we'],
#  [65, 'your'],
#  [65, 'than'],
#  [65, "don't"],
#  [64, 'much'],
#  [63, 'because'],
#  [61, 'time'],
#  [60, 'these'],
#  [60, 'been'],
#  [59, 'how'],
#  [59, 'got'],
#  [57, 'which'],
#  [57, 'were'],
#  [57, 'am'],
#  [56, 'movie'],
#  [56, 'do'],
#  [55, 'could'],
#  [54, 'first'],
#  [53, 'many'],
#  [53, 'make'],
#  [52, 'old'],
#  [52, 'into'],
#  [51, 'any'],
#  [50, 'game'],
#  [50, "can't"],
#  [49, 'new'],
#  [49, 'most'],
#  [48, 'little'],
#  [48, 'did'],
#  [48, 'after'],
#  [47, 'then'],
#  [47, 'find'],
#  [47, 'better'],
#  [46, "i'm"],
#  [46, 'also'],
#  [45, 'book.'],
#  [44, 'too'],
#  [44, 'its'],
#  [44, 'cd'],
#  [44, 'bought'],
#  [43, 'want'],
#  [43, 'think'],
#  [43, 'people'],
#  [42, 'their'],
#  [42, 'never'],
#  [42, 'books'],
#  [42, 'best'],
#  [41, 'still'],
#  [41, 'know'],
#  [40, 'well'],
#  [40, 'story'],
#  [38, 'same'],
#  [38, 'recommend'],
#  [38, 'now'],
#  [38, 'does'],
#  [37, 'music'],
#  [36, 'through'],
#  [36, 'should'],
#  [36, 'over'],
#  [36, 'found'],
#  [35, 'say'],
#  [35, 'reading'],
#  [35, 'every'],
#  [35, 'ever'],
#  [35, 'buy'],
#  [34, 'product'],
#  [34, 'give'],
#  [34, 'back'],
#  [33, 'work'],
#  [33, 'while'],
#  [33, 'dvd'],
#  [33, "didn't"],
#  [32, 'another'],
#  [31, 'thing'],
#  [31, 'see'],
#  [31, 'must'],
#  [31, 'go'],
#  [31, 'actually'],
#  [30, 'years'],
#  [30, 'two'],
#  [30, 'thought'],
#  [30, 'made'],
#  [30, 'going'],
#  [30, 'characters'],
#  [30, 'bad'],
#  [29, 'year'],
#  [28, 'where'],
#  [28, 'those'],
#  [28, 'plot'],
#  [28, 'however,'],
#  [28, 'funny'],
#  [28, 'daughter'],
#  [27, 'something'],
#  [27, 'since'],
#  [27, 'our'],
#  [27, 'need'],
#  [27, 'anyone'],
#  [27, '2'],
#  [26, 'way'],
#  [26, 'put'],
#  [26, 'off'],
#  [26, 'loved'],
#  [26, 'looking'],
#  [26, 'big'],
#  [26, 'album'],
#  [25, 'worth'],
#  [25, 'waste'],
#  [25, 'use'],
#  [25, 'series'],
#  [25, 'money'],
#  [25, 'makes'],
#  [25, 'each'],
#  [25, 'dark'],
#  [25, 'come'],
#  [25, 'before'],
#  [24, 'used'],
#  [24, 'set'],
#  [24, 'lot'],
#  [24, "i've"],
#  [24, 'everything'],
#  [24, '&'],
#  [23, 'watch'],
#  [23, 'songs'],
#  [23, 'real'],
#  [23, 'play'],
#  [23, '3'],
#  [22, 'seems'],
#  [22, 'received'],
#  [22, 'long'],
#  [22, 'last'],
#  [22, 'keep'],
#  [22, 'it,'],
#  [22, 'him'],
#  [22, 'excellent'],
#  [22, 'author'],
#  [22, 'around'],
#  [22, 'adam'],
#  [21, 'right'],
#  [21, 'loves'],
#  [21, 'let'],
#  [21, 'fun'],
#  [21, 'few'],
#  [21, "doesn't"],
#  [21, 'although'],
#  [21, 'again'],
#  [20, 'writing'],
#  [20, "wouldn't"],
#  [20, 'pretty'],
#  [20, 'might'],
#  [20, 'here'],
#  [20, 'easy'],
#  [20, 'down'],
#  [20, 'bit'],
#  [20, 'believe'],
#  [20, 'almost'],
#  [19, 'played'],
#  [19, 'may'],
#  [19, 'hard'],
#  [19, 'enough'],
#  [19, 'enjoy'],
#  [19, '5'],
#  [18, 'written'],
#  [18, 'whole'],
#  [18, 'us'],
#  [18, 'until'],
#  [18, 'time.'],
#  [18, 'next'],
#  [18, 'life'],
#  [18, 'film'],
#  [18, 'feel'],
#  [18, 'economics'],
#  [18, 'disappointed'],
#  [18, 'cornwell'],
#  [18, 'both'],
#  [18, 'book,'],
#  [17, 'wish'],
#  [17, 'using'],
#  [17, 'sure'],
#  [17, 'song'],
#  [17, 'someone'],
#  [17, 'scarpetta'],
#  [17, 'reviews'],
#  [17, 'quality'],
#  [17, 'novel'],
#  [17, 'movies'],
#  [17, 'maybe'],
#  [17, 'making'],
#  [17, 'kind'],
#  [17, 'highly'],
#  [17, 'end'],
#  [17, 'amazon'],
#  [16, "you're"],
#  [16, 'wait'],
#  [16, 'three'],
#  [16, 'though'],
#  [16, 'thomas'],
#  [16, 'seem'],
#  [16, 'said'],
#  [16, 'read.'],
#  [16, 'original'],
#  [16, 'ordered'],
#  [16, 'nothing'],
#  [16, 'movie.'],
#  [16, 'me.'],
#  [16, 'look'],
#  [16, 'least'],
#  [16, 'interesting'],
#  [16, 'fact'],
#  [16, "couldn't"],
#  [16, 'came'],
#  [16, 'again.'],
#  [16, '.'],
#  [15, 'worst'],
#  [15, 'wonderful'],
#  [15, "won't"],
#  [15, 'without'],
#  [15, 'tried'],
#  [15, 'take'],
#  [15, 'such'],
#  [15, 'probably'],
#  [15, 'poor'],
#  [15, 'patricia'],
#  [15, 'nice'],
#  [15, 'information'],
#  [15, 'heard'],
#  [15, 'gets'],
#  [15, 'favorite'],
#  [15, 'blocks'],
#  [15, 'always'],
#  [15, '4'],
#  [14, 'young'],
#  [14, 'why'],
#  [14, "wasn't"],
#  [14, 'understand'],
#  [14, 'sound'],
#  [14, 'son'],
#  [14, 'several'],
#  [14, 'purchased'],
#  [14, 'lots'],
#  [14, 'live'],
#  [14, "isn't"],
#  [14, 'game.'],
#  [14, 'felt'],
#  [14, 'family'],
#  [14, 'enjoyed'],
#  [14, 'done'],
#  [14, 'between'],
#  [14, 'anything'],
#  [13, 'world'],
#  [13, 'version'],
#  [13, "they're"],
#  [13, 'saw'],
#  [13, 'romance'],
#  [13, 'others'],
#  [13, 'needed'],
#  [13, 'ms.'],
#  [13, 'main'],
#  [13, 'hear'],
#  [13, 'having'],
#  [13, 'half'],
#  [13, 'getting'],
#  [13, 'game,'],
#  [13, 'full'],
#  [13, 'fan'],
#  [13, 'day'],
#  [13, 'couple'],
#  [13, 'comes'],
#  [13, 'absolutely'],
#  [13, 'able'],
#  [12, 'under'],
#  [12, 'tracks'],
#  [12, 'took'],
#  [12, 'title'],
#  [12, 'time,'],
#  [12, 'this,'],
#  [12, 'tell'],
#  [12, 'stories'],
#  [12, 'stars'],
#  [12, 'star'],
#  [12, 'second'],
#  [12, 'sandler'],
#  [12, 'rather'],
#  [12, 'quite'],
#  [12, 'please'],
#  [12, 'place'],
#  [12, 'one.'],
#  [12, 'once'],
#  [12, 'left'],
#  [12, 'kept'],
#  [12, 'instead'],
#  [12, 'history'],
#  [12, 'help'],
#  [12, 'friends'],
#  [12, 'figure'],
#  [12, 'far'],
#  [12, 'entire'],
#  [12, 'different'],
#  [12, 'dance'],
#  [12, 'cash'],
#  [12, 'barbie'],
#  [12, 'all,'],
#  [12, '--'],
#  [11, "you'll"],
#  [11, 'write'],
#  [11, 'went'],
#  [11, 'video'],
#  [11, 'u'],
#  [11, 'truly'],
#  [11, 'told'],
#  [11, 'style'],
#  [11, 'start'],
#  [11, 'special'],
#  [11, 'songs.'],
#  [11, 'series,'],
#  [11, 'return'],
#  [11, 'purchase'],
#  [11, 'price'],
#  [11, 'pictures'],
#  [11, 'pick'],
#  [11, 'person'],
#  [11, 'money.'],
#  [11, 'mix'],
#  [11, 'missing'],
#  [11, 'man'],
#  [11, 'listen'],
#  [11, 'killer'],
#  [11, 'kay'],
#  [11, "i'd"],
#  [11, 'home'],
#  [11, 'happy'],
#  [11, 'giving'],
#  [11, 'games'],
#  [11, 'difficult'],
#  [11, 'definitely'],
#  [11, 'box'],
#  [11, 'away'],
#  [10, 'work.'],
#  [10, 'various'],
#  [10, 'up.'],
#  [10, 'trying'],
#  [10, 'true'],
#  [10, 'track'],
#  [10, 'things'],
#  [10, 'show'],
#  [10, 'short'],
#  [10, 'seemed'],
#  [10, 'plays'],
#  [10, 'playing'],
#  [10, 'out.'],
#  [10, 'order'],
#  [10, 'night'],
#  [10, 'looked'],
#  [10, 'likes'],
#  [10, 'liked'],
#  [10, 'kids'],
#  [10, 'hours'],
#  [10, 'hot'],
#  [10, 'hope'],
#  [10, 'guess'],
#  [10, 'food'],
#  [10, 'end.'],
#  [10, 'christmas'],
#  [10, 'cat'],
#  [10, 'amazing'],
#  [10, 'all.'],
#  [10, 'ago'],
#  [10, '6'],
#  [9, 'wrote'],
#  [9, 'worked'],
#  [9, 'watching'],
#  [9, 'wanted'],
#  [9, 'usually'],
#  [9, 'up,'],
#  [9, 'tv'],
#  [9, 'turn'],
#  [9, 'try'],
#  [9, 'top'],
#  [9, 'too.'],
#  [9, 'together'],
#  [9, 'times'],
#  [9, 'them.'],
#  [9, 'that,'],
#  [9, "that's"],
#  [9, 'system'],
#  [9, 'story.'],
#  [9, 'sent'],
#  [9, 'screen'],
#  [9, 'review'],
#  [9, 'replace'],
#  [9, 'part'],
#  [9, 'pages'],
#  [9, 'own'],
#  [9, 'now.'],
#  [9, 'looks'],
#  [9, 'longer'],
#  [9, 'limit'],
#  [9, 'light'],
#  [9, 'learn'],
#  [9, 'job'],
#  [9, 'interested'],
#  [9, 'idea'],
#  [9, 'hoping'],
#  [9, 'high'],
#  [9, 'henry'],
#  [9, 'guy'],
#  [9, "feehan's"],
#  [9, 'economic'],
#  [9, 'company'],
#  [9, 'comedy'],
#  [9, 'christine'],
#  [9, 'character'],
#  [9, 'care'],
#  [9, 'buying'],
#  [9, 'boy'],
#  [9, 'beginning'],
#  [9, 'basic'],
#  [9, 'authors'],
#  [9, 'arrived'],
#  [8, "you've"],
#  [8, 'yoruba'],
#  [8, 'yet'],
#  [8, 'writer'],
#  [8, 'well.'],
#  [8, 'view'],
#  [8, 'unless'],
#  [8, 'totally'],
#  [8, 'this.'],
#  [8, "there's"],
#  [8, 'story,'],
#  [8, 'soundtrack'],
#  [8, 'size'],
#  [8, 'side'],
#  [8, 'shipping'],
#  [8, 'seller'],
#  [8, 'seen'],
#  [8, 'says'],
#  [8, 'rest'],
#  [8, 'remote'],
#  [8, 'quicktime'],
#  [8, 'quick'],
#  [8, 'problem'],
#  [8, 'previous'],
#  [8, 'pop'],
#  [8, 'player'],
#  [8, 'pillow'],
#  [8, 'picture'],
#  [8, 'perfect'],
#  [8, 'pay'],
#  [8, 'on.'],
#  [8, 'number'],
#  [8, 'mystery'],
#  [8, 'music.'],
#  [8, 'music,'],
#  [8, 'minute'],
#  [8, 'major'],
#  [8, 'listening'],
#  [8, 'line'],
#  [8, 'learning'],
#  [8, 'it!'],
#  [8, 'inside'],
#  [8, 'hair'],
#  [8, 'gives'],
#  [8, 'girl'],
#  [8, 'gave'],
#  [8, 'four'],
#  [8, 'fine'],
#  [8, 'fall'],
#  [8, 'expected'],
#  [8, 'decided'],
#  [8, 'crime'],
#  [8, 'cover'],
#  [8, 'course'],
#  [8, 'cool'],
#  [8, 'control'],
#  [8, 'completely'],
#  [8, 'color'],
#  [8, 'cannot'],
#  [8, 'call'],
#  [8, 'boys'],
#  [8, 'boring'],
#  [8, 'being'],
#  [8, 'batteries'],
#  [8, 'available'],
#  [8, 'audio'],
#  [8, 'also,'],
#  [8, '400'],
#  [8, '1'],
#  [8, '"the'],
#  [7, 'works'],
#  [7, 'within'],
#  [7, "what's"],
#  [7, 'wear'],
#  [7, 'water'],
#  [7, 'type'],
#  [7, 'toy'],
#  [7, 'topics'],
#  [7, 'too,'],
#  [7, 'thinking'],
#  [7, 'tess'],
#  [7, 'telling'],
#  [7, 'tape'],
#  [7, 'talking'],
#  [7, 'tale'],
#  [7, 'stuff'],
#  [7, 'store'],
#  [7, 'started'],
#  [7, 'stand'],
#  [7, 'sometimes'],
#  [7, 'software'],
#  [7, 'smith'],
#  [7, 'single'],
#  [7, 'simply'],
#  [7, 'series.'],
#  [7, 'sense'],
#  [7, 'seeing'],
#  [7, 'scenes'],
#  [7, 'sad'],
#  [7, 'remember'],
#  [7, 'read,'],
#  [7, 'point'],
#  [7, 'piece'],
#  [7, 'personal'],
#  [7, 'perhaps'],
#  [7, 'parents'],
#  [7, 'paid'],
#  [7, 'none'],
#  [7, 'nicoletta'],
#  [7, 'needs'],
#  [7, 'name'],
#  [7, 'myself'],
#  [7, 'more.'],
#  [7, 'months'],
#  [7, 'mind'],
#  [7, 'lost'],
#  [7, 'library'],
#  [7, 'letters'],
#  [7, 'less'],
#  [7, 'knew'],
#  [7, 'itself'],
#  [7, 'intelligent'],
#  [7, 'however'],
#  [7, 'hooked'],
#  [7, 'here.'],
#  [7, 'happened'],
#  [7, 'guys'],
#  [7, 'girls'],
#  [7, 'gift'],
#  [7, 'forward'],
#  [7, 'formula'],
#  [7, 'finally'],
#  [7, 'film.'],
#  [7, 'fast'],
#  [7, 'fans'],
#  [7, 'fact,'],
#  [7, 'expect'],
#  [7, 'excited'],
#  [7, 'except'],
#  [7, 'especially'],
#  [7, 'else'],
#  [7, 'dvd.'],
#  [7, 'decent'],
#  [7, 'deal'],
#  [7, 'daughters'],
#  [7, 'computer'],
#  [7, 'coming'],
#  [7, 'clearly'],
#  [7, 'children.'],
#  [7, 'changed'],
#  [7, 'books.'],
#  [7, 'body'],
#  [7, 'blocks.'],
#  [7, 'become'],
#  [7, 'amazon.'],
#  [7, 'again,'],
#  [6, 'yourself'],
#  [6, 'years.'],
#  [6, 'whether'],
#  [6, 'wanting'],
#  [6, 'typical'],
#  [6, 'turns'],
#  [6, 'tries'],
#  [6, 'timber'],
#  [6, 'takes'],
#  [6, 'support'],
#  [6, 'spent'],
#  [6, 'smells'],
#  [6, 'smaller'],
#  [6, 'skating'],
#  [6, 'shows'],
#  [6, 'serious'],
#  [6, 'send'],
#  [6, 'scarletti'],
#  [6, 'said,'],
#  [6, 'room'],
#  [6, 'reason'],
#  [6, 'rap'],
#  [6, 'product.'],
#  [6, 'problem.'],
#  [6, 'price.'],
#  [6, 'place.'],
#  [6, 'performance'],
#  [6, 'parts'],
#  [6, 'page'],
#  [6, 'often'],
#  [6, 'now,'],
#  [6, 'nearly'],
#  [6, 'me,'],
#  [6, 'lucky'],
#  [6, 'listened'],
#  [6, 'leave'],
#  [6, 'language'],
#  [6, "juvenile's"],
#  [6, 'item'],
#  [6, 'italian'],
#  [6, 'included'],
#  [6, 'husband'],
#  [6, 'house'],
#  [6, 'hour'],
#  [6, 'horror'],
#  [6, 'hold'],
#  [6, 'helps'],
#  [6, "he's"],
#  [6, 'hazlitt'],
#  [6, "hasn't"],
#  [6, 'guide'],
#  [6, 'government'],
#  [6, 'good.'],
#  [6, 'glad'],
#  [6, 'given'],
#  [6, 'gault'],
#  [6, 'friend'],
#  [6, 'final'],
#  [6, 'figured'],
#  [6, 'feels'],
#  [6, 'feehan'],
#  [6, 'everyone'],
#  [6, 'english'],
#  [6, 'effort'],
#  [6, 'early'],
#  [6, 'doing'],
#  [6, 'despite'],
#  [6, 'day.'],
#  [6, 'covers'],
#  [6, 'country'],
#  [6, 'cost'],
#  [6, 'correct'],
#  [6, 'consider'],
#  [6, 'complete'],
#  [6, 'clear'],
#  [6, 'chocolate'],
#  [6, 'children'],
#  [6, 'child'],
#  [6, 'check'],
#  [6, 'charger'],
#  [6, 'cd.'],
#  [6, 'case'],
#  [6, 'car'],
#  [6, 'camcorder'],
#  [6, 'books,'],
#  [6, 'better.'],
#  [6, 'based'],
#  [6, 'baseball'],
#  [6, 'attention'],
#  [6, 'ash'],
#  [6, 'appreciate'],
#  [6, 'amount'],
#  [6, 'american'],
#  [6, 'alot'],
#  [6, 'album.'],
#  [6, 'age'],
#  [6, 'actual'],
#  [6, 'across'],
#  [6, '(i'],
#  [6, '"i'],
#  [5, 'you.'],
#  [5, 'yes,'],
#  [5, 'wrong'],
#  [5, 'writing.'],
#  [5, 'wondering'],
#  [5, "weren't"],
#  [5, 'weeks'],
#  [5, 'week'],
#  [5, 'web'],
#  [5, 'wayne'],
#  [5, 'vhs'],
#  [5, 'value'],
#  [5, 'uses'],
#  [5, 'true.'],
#  [5, 'trip'],
#  [5, 'travel'],
#  [5, 'toe'],
#  [5, 'to.'],
#  [5, 'throw'],
#  [5, 'theory'],
#  [5, 'test'],
#  [5, 'tells'],
#  [5, 'technical'],
#  [5, 'talk'],
#  [5, 'taken'],
#  [5, 'super'],
#  [5, 'stupid'],
#  [5, 'stopped'],
#  [5, 'state'],
#  [5, 'starting'],
#  [5, 'spend'],
#  [5, 'sounds'],
#  [5, 'sort'],
#  [5, 'slow'],
#  [5, 'sitting'],
#  [5, 'simple'],
#  [5, 'showed'],
#  [5, "she's"],
#  [5, 'sell'],
#  [5, 'school'],
#  [5, 'say,'],
#  [5, "sandler's"],
#  [5, 'required'],
#  [5, 'relationship'],
#  [5, 'reference'],
#  [5, 'reason,'],
#  [5, 'reader'],
#  [5, 'quickly'],
#  [5, 'public'],
#  [5, 'problems'],
#  [5, 'poorly'],
#  [5, 'political'],
#  [5, 'play.'],
#  [5, 'people.'],
#  [5, 'pass'],
#  [5, 'pair'],
#  [5, 'packaging'],
#  [5, 'opinion'],
#  [5, 'onto'],
#  [5, 'ones'],
#  [5, 'novel.'],
#  [5, 'notice'],
#  [5, 'nice.'],
#  [5, 'muslim'],
#  [5, 'much.'],
#  [5, 'movie,'],
#  [5, 'money,'],
#  [5, 'modern'],
#  [5, 'minutes'],
#  [5, 'memory'],
#  [5, 'male'],
#  [5, 'lil'],
#  [5, 'lesson'],
#  [5, 'law'],
#  [5, 'late'],
#  [5, 'l.'],
#  [5, 'keys'],
#  [5, 'keeps'],
#  [5, 'jvc'],
#  [5, 'jokes'],
#  [5, 'japanese'],
#  [5, 'is,'],
#  [5, 'image'],
#  [5, "i'll"],
#  [5, 'human'],
#  [5, 'huge'],
#  [5, 'hotel'],
#  [5, 'himself'],
#  [5, 'him.'],
#  [5, 'herself'],
#  [5, 'help.'],
#  [5, 'heart'],
#  [5, 'group'],
#  [5, 'graphics'],
#  [5, 'gothic'],
#  [5, 'god'],
#  [5, 'glider'],
#  [5, 'george'],
#  [5, 'funny.'],
#  [5, 'fun.'],
#  [5, 'fun,'],
#  [5, 'fully'],
#  [5, 'free'],
#  [5, 'forget'],
#  [5, 'forensic'],
#  [5, 'finds'],
#  [5, 'filled'],
#  [5, 'female'],
#  [5, 'fell'],
#  [5, 'feet'],
#  [5, 'fascinating'],
#  [5, 'famous'],
#  [5, 'extremely'],
#  [5, 'example'],
#  [5, 'exact'],
#  [5, 'europe'],
#  [5, 'etc.'],
#  [5, 'essay'],
#  [5, 'ends'],
#  [5, 'ending.'],
#  [5, 'ending'],
#  [5, 'else.'],
#  [5, 'during'],
#  [5, 'dull'],
#  [5, 'due'],
#  [5, 'down.'],
#  [5, 'done.'],
#  [5, 'do.'],
#  [5, 'details'],
#  [5, 'design'],
#  [5, 'descriptions'],
#  [5, 'description'],
#  [5, 'de'],
#  [5, 'darkness'],
#  [5, 'creative'],
#  [5, "cornwell's"],
#  [5, 'cooking'],
#  [5, 'contacted'],
#  [5, 'concept'],
#  [5, 'colorful'],
#  [5, 'colin'],
#  [5, 'close'],
#  [5, 'clean'],
#  [5, 'claims'],
#  [5, 'chrono'],
#  [5, 'chinese'],
#  [5, 'change'],
#  [5, 'cereal'],
#  [5, 'camera'],
#  [5, 'called'],
#  [5, 'cable'],
#  [5, 'build'],
#  [5, 'bring'],
#  [5, 'brief'],
#  [5, 'beyond'],
#  [5, 'bench'],
#  [5, 'behind'],
#  [5, 'beautifully'],
#  [5, 'beautiful'],
#  [5, 'beats'],
#  [5, 'be.'],
#  [5, 'band'],
#  [5, 'back.'],
#  [5, 'b'],
#  [5, 'awesome'],
#  [5, 'average'],
#  [5, 'attempts'],
#  [5, 'appears'],
#  [5, 'appear'],
#  [5, 'apart'],
#  [5, 'anybody'],
#  [5, 'among'],
#  [5, 'america'],
#  [5, 'already'],
#  [5, 'advanced'],
#  [5, 'add'],
#  [5, 'above'],
#  [5, '100'],
#  [5, '10'],
#  [5, '(and'],
#  [5, '!'],
#  [4, 'years,'],
#  [4, "ya'll"],
#  [4, 'y'],
#  [4, 'wrong.'],
#  [4, 'worse'],
#  [4, 'worn'],
#  [4, 'wooden'],
#  [4, 'woman'],
#  [4, 'wife'],
#  [4, 'well,'],
#  [4, 'weak'],
#  [4, 'way.'],
#  [4, 'war'],
#  [4, 'wants'],
#  [4, 'waiting'],
#  [4, 'voice'],
#  [4, 'via'],
#  [4, 'version,'],
#  [4, 'vcr'],
#  [4, 'usual'],
#  [4, 'user'],
#  [4, 'useful'],
#  [4, 'use.'],
#  [4, 'unusual'],
#  [4, 'twist'],
#  [4, 'turned'],
#  [4, 'trash'],
#  [4, 'total'],
#  [4, 'topper'],
#  [4, 'times.'],
#  [4, 'through.'],
#  [4, 'there.'],
#  [4, 'theoretical'],
#  [4, 'them,'],
#  [4, 'them!'],
#  [4, 'tha'],
#  [4, 'terrible'],
#  [4, 'system.'],
#  [4, 'swords'],
#  [4, 'suggest'],
#  [4, 'subject'],
#  [4, 'strong'],
#  [4, 'stay'],
#  [4, 'stars.'],
#  [4, 'stars,'],
#  [4, 'star.'],
#  [4, 'standard'],
#  [4, 'southern'],
#  [4, 'sourdough'],
#  [4, 'sony'],
#  [4, 'somewhere'],
#  [4, 'so,'],
#  [4, 'small'],
#  [4, 'similar'],
#  [4, 'silly'],
#  [4, 'shit'],
#  [4, 'shipped'],
#  [4, 'sharp'],
#  [4, 'shame'],
#  [4, 'sex'],
#  [4, 'seller.'],
#  [4, 'seen.'],
#  [4, 'sections'],
#  [4, 'search'],
#  [4, 'science'],
#  [4, 'scene'],
#  [4, 'saying'],
#  [4, 'save'],
#  [4, 'sample'],
#  [4, 'sadly,'],
#  [4, 'running'],
#  [4, 'run'],
#  [4, 'romantic'],
#  [4, 'role.'],
#  [4, 'ride'],
#  [4, 'reviewer'],
#  [4, 'returned'],
#  ...]

# %%
# Out:
# None
